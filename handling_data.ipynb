# %%
import pandas as pd
import numpy as np
import io
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/leduin/Desktop/Hub/Results/aga_radius.csv")

fig, axes = plt.subplots(3, 1, sharex=True, figsize=(10,8))
fig.subplots_adjust(hspace=0)

df.boxplot(column='time', by='radius', ax=axes[0])
df.boxplot(column='steps', by='radius', ax=axes[1])
df.boxplot(column='effectiveness', by='radius', ax=axes[2])

axes[0].set_title('')
axes[1].set_title('')
axes[2].set_title('')

axes[0].set_ylabel('time (s)')
axes[1].set_ylabel('steps')
axes[2].set_ylabel('effectiveness [0,1]')

plt.xlabel("radius")

fig.suptitle('')
plt.savefig("/home/leduin/Desktop/Hub/Images/results/aga_radius.svg")

# %%
df = pd.read_csv("/home/leduin/Desktop/Hub/Results/aga_movement.csv")

fig, axes = plt.subplots(3, 1, sharex=True, figsize=(10,8))
fig.subplots_adjust(hspace=0)

df.boxplot(column='time', by='movement', ax=axes[0])
df.boxplot(column='steps', by='movement', ax=axes[1])
df.boxplot(column='effectiveness', by='movement', ax=axes[2])

axes[0].set_title('')
axes[1].set_title('')
axes[2].set_title('')

axes[0].set_ylabel('time (s)')
axes[1].set_ylabel('steps')
axes[2].set_ylabel('effectiveness [0,1]')

plt.xlabel("movement")

fig.suptitle('')
plt.savefig("/home/leduin/Desktop/Hub/Images/results/aga_movement.svg")

# %%
df = pd.read_csv("/home/leduin/Desktop/Hub/Results/aga_tolerance.csv")

fig, axes = plt.subplots(3, 1, sharex=True, figsize=(10,8))
fig.subplots_adjust(hspace=0)

df.boxplot(column='time', by='tolerance', ax=axes[0])
df.boxplot(column='steps', by='tolerance', ax=axes[1])
df.boxplot(column='effectiveness', by='tolerance', ax=axes[2])

axes[0].set_title('')
axes[1].set_title('')
axes[2].set_title('')

axes[0].set_ylabel('time (s)')
axes[1].set_ylabel('steps')
axes[2].set_ylabel('effectiveness [0,1]')

plt.xlabel("tolerance")

fig.suptitle('')
plt.savefig("/home/leduin/Desktop/Hub/Images/results/aga_tolerance.svg")

# %%
df = pd.read_csv("/home/leduin/Desktop/Hub/Results/aga_deadlock_mov.csv")

fig, axes = plt.subplots(3, 1, sharex=True, figsize=(10,9))
fig.subplots_adjust(hspace=0)

df.boxplot(column='time', by='deadlock_mov', ax=axes[0])
df.boxplot(column='steps', by='deadlock_mov', ax=axes[1])
df.boxplot(column='effectiveness', by='deadlock_mov', ax=axes[2])

axes[0].set_title('')
axes[1].set_title('')
axes[2].set_title('')

axes[0].set_ylabel('time (s)')
axes[1].set_ylabel('steps')
axes[2].set_ylabel('effectiveness [0,1]')

plt.xlabel("deadlock_mov")

fig.suptitle('')
plt.savefig("/home/leduin/Desktop/Hub/Images/results/aga_deadlock_mov.svg")

# %%
df = pd.read_csv("/home/leduin/Desktop/Hub/Results/aga_previous.csv")

fig, axes = plt.subplots(3, 1, sharex=True, figsize=(10,9))
fig.subplots_adjust(hspace=0)

df.boxplot(column='time', by='previous', ax=axes[0])
df.boxplot(column='steps', by='previous', ax=axes[1])
df.boxplot(column='effectiveness', by='previous', ax=axes[2])

axes[0].set_title('')
axes[1].set_title('')
axes[2].set_title('')

axes[0].set_ylabel('time (s)')
axes[1].set_ylabel('steps')
axes[2].set_ylabel('effectiveness [0,1]')

plt.xlabel("previous")

fig.suptitle('')
plt.savefig("/home/leduin/Desktop/Hub/Images/results/aga_previous.svg")

# %%
df = pd.read_csv("/home/leduin/Desktop/Hub/Results/orca.csv")

fig, axes = plt.subplots(2, 1, sharex=True, figsize=(10,6))
fig.subplots_adjust(hspace=0)

df.boxplot(column='time', by='robots', ax=axes[0])
df.boxplot(column='steps', by='robots', ax=axes[1])

axes[0].set_title('')
axes[1].set_title('')

axes[0].set_ylabel('time (s)')
axes[1].set_ylabel('steps')

plt.xlabel("robots")

fig.suptitle('')
plt.savefig("/home/leduin/Desktop/Hub/Images/results/orca_figure.svg")
