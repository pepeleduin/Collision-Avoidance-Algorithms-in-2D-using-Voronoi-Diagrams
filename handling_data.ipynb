# %%
import pandas as pd
import numpy as np
import io
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_csv("/home/leduin/Escritorio/Tesis/Resultados/Datos/aga_radius.csv")

fig, axes = plt.subplots(3, 1, sharex=True, figsize=(10,8))
fig.subplots_adjust(hspace=0)

df.boxplot(column='time', by='radius', ax=axes[0])
df.boxplot(column='steps', by='radius', ax=axes[1])
df.boxplot(column='effectiveness', by='radius', ax=axes[2])

axes[0].set_title('')
axes[1].set_title('')
axes[2].set_title('')

axes[0].set_ylabel('time (s)')
axes[1].set_ylabel('steps')
axes[2].set_ylabel('effectiveness [0,1]')

plt.xlabel("radius")

fig.suptitle('')
plt.savefig("/home/leduin/Escritorio/Tesis/Resultados/Imagenes/aga_radius.svg")

# %%
df = pd.read_csv("/home/leduin/Escritorio/Tesis/Resultados/Datos/aga_tolerance.csv")

fig, axes = plt.subplots(4, 1, sharex=True, figsize=(10,12))
fig.subplots_adjust(hspace=0)

df.boxplot(column='time', by='tolerance', ax=axes[0])
df.boxplot(column='steps', by='tolerance', ax=axes[1])
df.boxplot(column='effectiveness', by='tolerance', ax=axes[2])

x = []
y = []
acc_tim = df.mean()["time"]
acc_stp = df.mean()["steps"]
acc_eff = df.mean()["effectiveness"]
for i in range(1,21):
    if i < 11:
        temp_df = df.loc[df["tolerance"]==round(0.1*i,2)]
    elif i < 19:
        temp_df = df.loc[df["tolerance"]==(i+1)%10]
    temp_tim = temp_df.mean()["time"]
    temp_stp = temp_df.mean()["steps"]
    temp_eff = temp_df.mean()["effectiveness"]
    temp_sum = (temp_tim/acc_tim)+(temp_stp/acc_stp)+((1-temp_eff)/acc_eff)
    x.append(i)
    y.append(temp_sum)
axes[3].plot(x,y)
axes[3].grid()

axes[0].set_title('')
axes[1].set_title('')
axes[2].set_title('')

axes[0].set_ylabel('time (s)')
axes[1].set_ylabel('steps')
axes[2].set_ylabel('effectiveness [0,1]')
axes[3].set_ylabel('cost')

plt.xlabel("tolerance")

fig.suptitle('')
plt.savefig("/home/leduin/Escritorio/Tesis/Resultados/Imagenes/aga_tolerance.svg")

# %%
40*math.sqrt(5)
# Out:
# 89.44271909999159

# %%
df = pd.read_csv("/home/leduin/Escritorio/Tesis/Resultados/Datos/aga_movement.csv")

fig, axes = plt.subplots(4, 1, sharex=True, figsize=(10,12))
fig.subplots_adjust(hspace=0)

df.boxplot(column='time', by='movement', ax=axes[0])
df.boxplot(column='steps', by='movement', ax=axes[1])
df.boxplot(column='effectiveness', by='movement', ax=axes[2])

x = []
y = []
acc_tim = df.mean()["time"]
acc_stp = df.mean()["steps"]
acc_eff = df.mean()["effectiveness"]
for i in range(1,15):
    if i < 11:
        temp_df = df.loc[df["movement"]==i]
    elif i < 19:
        temp_df = df.loc[df["movement"]==(i+1-10)*10]
    temp_tim = temp_df.mean()["time"]
    temp_stp = temp_df.mean()["steps"]
    temp_eff = temp_df.mean()["effectiveness"]
    temp_sum = (temp_tim/acc_tim)+(temp_stp/acc_stp)+((1-temp_eff)/acc_eff)
    x.append(i)
    y.append(temp_sum)
axes[3].plot(x,y)
axes[3].grid()

axes[0].set_title('')
axes[1].set_title('')
axes[2].set_title('')

axes[0].set_ylabel('time (s)')
axes[1].set_ylabel('steps')
axes[2].set_ylabel('effectiveness [0,1]')
axes[3].set_ylabel('cost')

plt.xlabel("movement")

fig.suptitle('')
plt.savefig("/home/leduin/Escritorio/Tesis/Resultados/Imagenes/aga_movement.svg")

# %%
df = pd.read_csv("/home/leduin/Escritorio/Tesis/Resultados/Datos/aga_deadlock_mov.csv")

fig, axes = plt.subplots(4, 1, sharex=True, figsize=(10,11))
fig.subplots_adjust(hspace=0)

df.boxplot(column='time', by='deadlock_mov', ax=axes[0])
df.boxplot(column='steps', by='deadlock_mov', ax=axes[1])
df.boxplot(column='effectiveness', by='deadlock_mov', ax=axes[2])

x = []
y = []
acc_tim = df.mean()["time"]
acc_stp = df.mean()["steps"]
acc_eff = df.mean()["effectiveness"]
for i in range(1,11):
    temp_df = df.loc[df["deadlock_mov"]==round(0.1*i,2)]
    temp_tim = temp_df.mean()["time"]
    temp_stp = temp_df.mean()["steps"]
    temp_eff = temp_df.mean()["effectiveness"]
    temp_sum = (temp_tim/acc_tim)+(temp_stp/acc_stp)+((1-temp_eff)/acc_eff)
    x.append(i)
    y.append(temp_sum)
axes[3].plot(x,y)
axes[3].grid()

axes[0].set_title('')
axes[1].set_title('')
axes[2].set_title('')

axes[0].set_ylabel('time (s)')
axes[1].set_ylabel('steps')
axes[2].set_ylabel('effectiveness [0,1]')
axes[3].set_ylabel('cost')

plt.xlabel("deadlock_mov")

fig.suptitle('')
plt.savefig("/home/leduin/Escritorio/Tesis/Resultados/Imagenes/aga_deadlock_mov.svg")

# %%
df = pd.read_csv("/home/leduin/Escritorio/Tesis/Resultados/Datos/aga_previous.csv")

fig, axes = plt.subplots(4, 1, sharex=True, figsize=(10,11))
fig.subplots_adjust(hspace=0)

df.boxplot(column='time', by='previous', ax=axes[0])
df.boxplot(column='steps', by='previous', ax=axes[1])
df.boxplot(column='effectiveness', by='previous', ax=axes[2])

x = []
y = []
acc_tim = df.mean()["time"]
acc_stp = df.mean()["steps"]
acc_eff = df.mean()["effectiveness"]
for i in range(1,11):
    temp_df = df.loc[df["previous"]==i]
    temp_tim = temp_df.mean()["time"]
    temp_stp = temp_df.mean()["steps"]
    temp_eff = temp_df.mean()["effectiveness"]
    temp_sum = (temp_tim/acc_tim)+(temp_stp/acc_stp)+((1-temp_eff)/acc_eff)
    x.append(i)
    y.append(temp_sum)
axes[3].plot(x,y)
axes[3].grid()

axes[0].set_title('')
axes[1].set_title('')
axes[2].set_title('')

axes[0].set_ylabel('time (s)')
axes[1].set_ylabel('steps')
axes[2].set_ylabel('effectiveness [0,1]')
axes[3].set_ylabel('cost')

plt.xlabel("previous")

fig.suptitle('')
plt.savefig("/home/leduin/Escritorio/Tesis/Resultados/Imagenes/aga_previous.svg")

# %%
df = pd.read_csv("/home/leduin/Escritorio/Tesis/Resultados/Datos/aga_num_robots.csv")

fig, axes = plt.subplots(4, 1, sharex=True, figsize=(10,11))
fig.subplots_adjust(hspace=0)

df.boxplot(column='time', by='num_robots', ax=axes[0])
df.boxplot(column='steps', by='num_robots', ax=axes[1])
df.boxplot(column='effectiveness', by='num_robots', ax=axes[2])

x = []
y = []
acc_tim = df.mean()["time"]
acc_stp = df.mean()["steps"]
acc_eff = df.mean()["effectiveness"]
for i in range(10):
    temp_df = df.loc[df["num_robots"]==(5+i)]
    temp_tim = temp_df.mean()["time"]
    temp_stp = temp_df.mean()["steps"]
    temp_eff = temp_df.mean()["effectiveness"]
    temp_sum = (temp_tim/acc_tim)+(temp_stp/acc_stp)+((1-temp_eff)/acc_eff)
    x.append(i)
    y.append(temp_sum)
axes[3].plot(x,y)
axes[3].grid()

axes[0].set_title('')
axes[1].set_title('')
axes[2].set_title('')

axes[0].set_ylabel('time (s)')
axes[1].set_ylabel('steps')
axes[2].set_ylabel('effectiveness [0,1]')
axes[3].set_ylabel('cost')

plt.xlabel("num robots")

fig.suptitle('')
plt.savefig("/home/leduin/Escritorio/Tesis/Resultados/Imagenes/aga_num_robots.svg")

# %%
df = pd.read_csv("/home/leduin/Desktop/Hub/Results/orca.csv")

fig, axes = plt.subplots(2, 1, sharex=True, figsize=(10,6))
fig.subplots_adjust(hspace=0)

df.boxplot(column='time', by='robots', ax=axes[0])
df.boxplot(column='steps', by='robots', ax=axes[1])

axes[0].set_title('')
axes[1].set_title('')

axes[0].set_ylabel('time (s)')
axes[1].set_ylabel('steps')

plt.xlabel("robots")

fig.suptitle('')
plt.savefig("/home/leduin/Desktop/Hub/Images/results/orca_figure.svg")
